# %% [markdown]
# # Plantilla de ejercicio — MATI
#
# No es un ejercicio real: es la maqueta que se copia al empezar uno nuevo. Cada bloque de abajo va en su propia caja de color reconocible de un vistazo (ver `CLAUDE.md` §4 / `GUIA_USO.md` §1.5 para el porqué de cada bloque). Sustituye el contenido de ejemplo por el del ejercicio real y borra las notas en *cursiva* entre corchetes.
#
# **Cómo usarla:** selecciona todas las celdas de abajo del `---` (desde "Ejercicio N"), cópialas al final de tu notebook de la entrega correspondiente, y sustituye el contenido.
#
# > ⚙️ **Kernel:** este notebook usa el kernel `Python (MATI .venv)`. Si al ejecutar aparece `ModuleNotFoundError`, ve a **Kernel → Change Kernel** y selecciónalo (ver `GUIA_USO.md` §1.2).

# %%
# Librerías que se usan en todo el notebook + funciones de dibujo compartidas
import networkx as nx            # crear y analizar grafos
import matplotlib.pyplot as plt  # dibujar (uso directo solo si mati_utils no basta)
import sympy as sp               # cálculos matemáticos exactos (combinatoria, matrices...)
import numpy as np               # operaciones numéricas auxiliares

from mati_utils import dibujar_grafo, dibujar_multigrafo, SEED  # funciones de dibujo, comentadas en notebooks/mati_utils.py

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-left:5px solid #888;background:#F2F2F2;padding:10px 14px;margin:10px 0;border-radius:4px;"><p><strong>📋 ENUNCIADO</strong></p><p><em>[Pega aquí el enunciado original del boletín, literal, sin resumir ni parafrasear.]</em></p></div>

# %% [markdown]
# <div style="border-left:5px solid #4C72B0;background:#EEF2FA;padding:10px 14px;margin:10px 0;border-radius:4px;"><p><strong>📚 TEORÍA</strong></p><p><em>[Explica en lenguaje llano, y solo después con notación formal, los conceptos mínimos que hacen falta para este ejercicio concreto — no un resumen general del tema. Define cualquier término nuevo la primera vez que aparece.]</em></p></div>

# %% [markdown]
# <div style="border-left:5px solid #8172B2;background:#F1EEF9;padding:10px 14px;margin:10px 0;border-radius:4px;"><p><strong>🔢 DATOS</strong></p><p><em>[Lista o tabla con los datos concretos que se extraen del enunciado: nº de nodos, aristas, pesos, matriz de partida... Lo que se vaya a usar en la celda de código de abajo.]</em></p></div>

# %%
# [Datos del enunciado como variables de Python — ejemplo:]
# n_nodos = 5
# aristas = [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1)]

# %% [markdown]
# <div style="border-left:5px solid #55A868;background:#EAF6ED;padding:10px 14px;margin:10px 0;border-radius:4px;"><p><strong>🧮 RESOLUCIÓN</strong></p><p><strong>[✍️ Trabajo del estudiante | 🤝 Con pistas de IA | ✅ Validado por IA | 🤖 Resuelto por IA — deja solo la insignia real]</strong></p><p><em>[Razonamiento y demostración matemática en LaTeX ($...$ / $$...$$), breve y riguroso. Formato completo "Definición/Proposición/Demostración/$lacksquare$" solo si el enunciado pide explícitamente una demostración formal.]</em></p><p><em>[Si la insignia es ✅ o 🤖, añade aquí una Discusión de 2-4 líneas: ¿era correcta la respuesta de la IA?, ¿por qué?, ¿qué se comprobó?]</em></p></div>

# %% [markdown]
# **💻 CÓDIGO**
#
# **[✍️ Trabajo del estudiante | 🤝 Con pistas de IA | ✅ Validado por IA | 🤖 Resuelto por IA — deja solo la insignia real]**

# %%
# [Un comentario por bloque lógico, pensado para quien todavía no tiene soltura con NetworkX/SymPy/Python.]
# [El código verifica/ilustra lo explicado en Resolución — no sustituye la justificación matemática.]

# Ejemplo mínimo (bórralo y sustitúyelo):
# G = nx.Graph()
# G.add_edges_from(aristas)
# print("nodos:", G.number_of_nodes(), "aristas:", G.number_of_edges())
# dibujar_grafo(G, titulo="Ejercicio N")

# %% [markdown]
# <div style="border-left:5px solid #C4A72E;background:#FBF6E3;padding:10px 14px;margin:10px 0;border-radius:4px;"><p><strong>🚀 AMPLIACIÓN <em>(opcional — borra este bloque entero si no se ha pedido una extensión del ejercicio con IA)</em></strong></p><p><em>[Extensión del problema propuesta/explorada con ayuda de IA.]</em></p></div>

# %% [markdown]
# <div style="border-left:5px solid #555;background:#F5F5F5;padding:10px 14px;margin:10px 0;border-radius:4px;"><p><strong>🤖 REGISTRO DE USO DE IA</strong></p><ul><li><strong>Herramienta(s) utilizada(s):</strong> <em>[p. ej. Claude Code (Claude Opus 5) / ChatGPT / Gemini / GitHub Copilot — indicar modelo si se conoce]</em></li><li><strong>Prompt(s) utilizado(s):</strong>  <ol><li>"..."</li></ol></li><li><strong>Fase del ejercicio en la que se usó IA:</strong> <em>[planteamiento / depuración del código / redacción / verificación]</em></li><li><strong>Verificación de no-alucinación realizada:</strong>  <ul>    <li>[ ] Resultado contrastado analíticamente a mano</li>    <li>[ ] Resultado contrastado con un caso/ejemplo conocido de la bibliografía</li>    <li>[ ] Resultado verificado computacionalmente con una implementación independiente</li>    <li>Detalle: "..."</li>  </ul></li><li><strong>Modificaciones realizadas sobre la propuesta de la IA:</strong> "..."</li><li><strong>Declaración de autoría:</strong> El razonamiento matemático y la decisión final han sido revisados y comprendidos por el/la estudiante, quien asume la responsabilidad del contenido entregado.</li></ul></div>💬 **¿Alguna duda sobre este ejercicio?** Pregunta lo que necesites, no hace falta esperar al final.
